# %%
import mne

# %%
filepath = r"C:\Users\bio86\Downloads\NIRS_01-29\subject 19\cnt.mat"

# %%
#Save the raw data in the dictionary
import numpy as np
from scipy.io import loadmat
import pandas as pd

nirs_matlab_files = loadmat(filepath)
    
nirs_channels = [item.flat[0] for item in nirs_matlab_files['cnt'][0][0]['clab'][0][0][0]]

# %%
channels = []

for i in range(36):
    channels.append(nirs_channels[i])
    channels.append(nirs_channels[i+36])

# %%
# Montage data

mnt = loadmat(r"C:\Users\bio86\Downloads\NIRS_01-29\subject 19\mnt.mat")

pos_3d = (mnt['mnt']['pos_3d'][0][0].T)/10

#Load source info

sources = (mnt['mnt']['source'][0][0][0][0][2].T)/10

#Load detector info

detectors = (mnt['mnt']['detector'][0][0][0][0][2].T)/10

# %%
pos_3d
# Out:
# array([[-4.53984172e-02,  8.91009747e-02,  5.06226775e-06],
#        [-3.35748481e-02,  9.31393778e-02,  1.40636367e-02],
#        [-1.80965897e-02,  9.24178683e-02,  3.36370489e-02],
#        [-1.56422671e-02,  9.87690203e-02,  1.01244447e-05],
#        [-0.00000000e+00,  9.80786108e-02,  1.95086160e-02],
#        [ 1.56472054e-02,  9.87682385e-02,  5.06218228e-06],
#        [ 1.80922060e-02,  9.24163938e-02,  3.36434577e-02],
#        [ 3.35764285e-02,  9.31387081e-02,  1.40642987e-02],
#        [ 4.54024360e-02,  8.90989271e-02,  0.00000000e+00],
#        [-0.00000000e+00, -9.80795866e-02,  1.95037098e-02],
#        [-1.56422672e-02, -9.87690208e-02,  0.00000000e+00],
#        [ 1.56422672e-02, -9.87690208e-02,  0.00000000e+00],
#        [-9.11263370e-02, -1.71144288e-02,  3.74578035e-02],
#        [-9.11265755e-02,  1.71325680e-02,  3.74489298e-02],
#        [-8.31500620e-02,  1.02005842e-05,  5.55523815e-02],
#        [-7.80929869e-02,  3.55430712e-02,  5.13631726e-02],
#        [-6.97413425e-02,  1.83870016e-02,  6.92680541e-02],
#        [-5.19973252e-02,  3.75618216e-02,  7.67162807e-02],
#        [-7.80965939e-02, -3.55243580e-02,  5.13706337e-02],
#        [-6.97416793e-02, -1.83656652e-02,  6.92733752e-02],
#        [-5.19884336e-02, -3.75395679e-02,  7.67331976e-02],
#        [-5.55594660e-02,  1.53056380e-05,  8.31453276e-02],
#        [-3.77596732e-02,  1.92342319e-02,  9.05773228e-02],
#        [-3.77544028e-02, -1.91984504e-02,  9.05871104e-02],
#        [ 3.77600435e-02,  1.92293213e-02,  9.05782111e-02],
#        [ 3.77540331e-02, -1.92033615e-02,  9.05862235e-02],
#        [ 5.55594664e-02,  1.02037587e-05,  8.31453281e-02],
#        [ 5.19973252e-02,  3.75618216e-02,  7.67162807e-02],
#        [ 6.97413425e-02,  1.83870016e-02,  6.92680541e-02],
#        [ 7.80929869e-02,  3.55430712e-02,  5.13631726e-02],
#        [ 7.80980056e-02, -3.55199113e-02,  5.13715623e-02],
#        [ 5.19894268e-02, -3.75351956e-02,  7.67346636e-02],
#        [ 6.97423312e-02, -1.83607466e-02,  6.92740227e-02],
#        [ 9.11263370e-02, -1.71144288e-02,  3.74578035e-02],
#        [ 8.31500620e-02,  1.02005842e-05,  5.55523815e-02],
#        [ 9.11265755e-02,  1.71325680e-02,  3.74489298e-02]])

# %%
sources
# Out:
# array([[       nan,        nan,        nan],
#        [-5.878e-02,  8.090e-02,  0.000e+00],
#        [-3.554e-02,  8.920e-02,  2.782e-02],
#        [-0.000e+00,  1.000e-01,  1.000e-05],
#        [ 3.553e-02,  8.919e-02,  2.783e-02],
#        [ 5.878e-02,  8.090e-02,  0.000e+00],
#        [-0.000e+00, -1.000e-01,  0.000e+00],
#        [       nan,        nan,        nan],
#        [-9.237e-02,  1.000e-05,  3.826e-02],
#        [-6.638e-02,  3.612e-02,  6.545e-02],
#        [-6.635e-02, -3.609e-02,  6.543e-02],
#        [-3.824e-02,  2.000e-05,  9.231e-02],
#        [ 3.824e-02,  1.000e-05,  9.231e-02],
#        [ 6.638e-02,  3.612e-02,  6.545e-02],
#        [ 6.635e-02, -3.608e-02,  6.543e-02],
#        [ 9.237e-02,  1.000e-05,  3.826e-02]])

# %%
pairs = mnt['mnt']['sd'][0][0]

# %%
n_channels = ['S2_D1 760','S2_D1 850','S3_D1 760','S3_D1 850','S3_D2 760','S3_D2 850','S4_D1 760',
              'S4_D1 850','S4_D2 760','S4_D2 850','S4_D3 760','S4_D3 850','S5_D2 760','S5_D2 850',
              'S5_D3 760','S5_D3 850','S6_D3 760','S6_D3 850','S7_D4 760','S7_D4 850','S7_D6 760',
              'S7_D6 850','S7_D7 760','S7_D7 850','S9_D5 760','S9_D5 850','S9_D9 760','S9_D9 850',
              'S9_D10 760','S9_D10 850','S10_D9 760','S10_D9 850','S10_D10 760','S10_D10 850',
              'S10_D11 760','S10_D11 850','S11_D5 760','S11_D5 850','S11_D10 760','S11_D10 850',
              'S11_D12 760','S11_D12 850','S12_D10 760','S12_D10 850','S12_D11 760','S12_D11 850',
              'S12_D12 760','S12_D12 850','S13_D13 760','S13_D13 850','S13_D14 760','S13_D14 850',
              'S13_D15 760','S13_D15 850','S14_D13 760','S14_D13 850','S14_D15 760','S14_D15 850',
              'S14_D16 760','S14_D16 850','S15_D8 760','S15_D8 850','S15_D14 760','S15_D14 850',
              'S15_D15 760','S15_D15 850','S16_D8 760','S16_D8 850','S16_D15 760','S16_D15 850',
              'S16_D16 760','S16_D16 850']

# %%
print(pairs)
# Out:
# [[ 2  1]
#  [ 3  1]
#  [ 3  2]
#  [ 4  1]
#  [ 4  2]
#  [ 4  3]
#  [ 5  2]
#  [ 5  3]
#  [ 6  3]
#  [ 7  4]
#  [ 7  6]
#  [ 7  7]
#  [ 9  5]
#  [ 9  9]
#  [ 9 10]
#  [10  9]
#  [10 10]
#  [10 11]
#  [11  5]
#  [11 10]
#  [11 12]
#  [12 10]
#  [12 11]
#  [12 12]
#  [13 13]
#  [13 14]
#  [13 15]
#  [14 13]
#  [14 15]
#  [14 16]
#  [15  8]
#  [15 14]
#  [15 15]
#  [16  8]
#  [16 15]
#  [16 16]]

# %%
# Initialize an info structure

#Info Structure for Low Work Load Raw Data
info = mne.create_info(
    ch_names=n_channels,
    ch_types=['fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw',
             'fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw','fnirs_raw'],
    sfreq=int(10))

# %%
info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: S2_D1 760, S2_D1 850, S3_D1 760, S3_D1 850, S3_D2 760, S3_D2 ...
#  chs: 72 FNIRS_RAW
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 5.0 Hz
#  meas_date: unspecified
#  nchan: 72
#  projs: []
#  sfreq: 10.0 Hz
# >

# %%
#Manually assign 3D coordinates to the info structure
x=0
for ch in range(36):
    for coor in range(3):
        info['chs'][x]['loc'][coor] = pos_3d[ch][coor]
        info['chs'][x+1]['loc'][coor] = pos_3d[ch][coor]
    x+=2

# %%
#Assign manually source locations

x=0
for ch in range(36):
    for coor in range(3):
        info['chs'][x]['loc'][coor+3] = sources[pairs[ch][0]-1][coor]
        info['chs'][x+1]['loc'][coor+3] = sources[pairs[ch][0]-1][coor]
    x+=2

# %%
#Assign manually detector locations

x=0
for ch in range(36):
    for coor in range(3):
        info['chs'][x]['loc'][coor+6] = detectors[pairs[ch][1]-1][coor]
        info['chs'][x+1]['loc'][coor+6] = detectors[pairs[ch][1]-1][coor]
    x+=2

# %%
#Assign wavelengths
for x in info['chs'][0::2]:
    x['loc'][9] = 760

for x in info['chs'][1::2]:
    x['loc'][9] = 850

# %%
info['chs']
# Out:
# [{'loc': array([-4.53984172e-02,  8.91009747e-02,  5.06226775e-06, -5.87800000e-02,
#           8.09000000e-02,  0.00000000e+00, -3.09000000e-02,  9.51100000e-02,
#           1.00000000e-05,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S2_D1 760',
#   'scanno': 1,
#   'logno': 1},
#  {'loc': array([-4.53984172e-02,  8.91009747e-02,  5.06226775e-06, -5.87800000e-02,
#           8.09000000e-02,  0.00000000e+00, -3.09000000e-02,  9.51100000e-02,
#           1.00000000e-05,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S2_D1 850',
#   'scanno': 2,
#   'logno': 2},
#  {'loc': array([-3.35748481e-02,  9.31393778e-02,  1.40636367e-02, -3.55400000e-02,
#           8.92000000e-02,  2.78200000e-02, -3.09000000e-02,  9.51100000e-02,
#           1.00000000e-05,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S3_D1 760',
#   'scanno': 3,
#   'logno': 3},
#  {'loc': array([-3.35748481e-02,  9.31393778e-02,  1.40636367e-02, -3.55400000e-02,
#           8.92000000e-02,  2.78200000e-02, -3.09000000e-02,  9.51100000e-02,
#           1.00000000e-05,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S3_D1 850',
#   'scanno': 4,
#   'logno': 4},
#  {'loc': array([-1.80965897e-02,  9.24178683e-02,  3.36370489e-02, -3.55400000e-02,
#           8.92000000e-02,  2.78200000e-02, -0.00000000e+00,  9.23000000e-02,
#           3.82400000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S3_D2 760',
#   'scanno': 5,
#   'logno': 5},
#  {'loc': array([-1.80965897e-02,  9.24178683e-02,  3.36370489e-02, -3.55400000e-02,
#           8.92000000e-02,  2.78200000e-02, -0.00000000e+00,  9.23000000e-02,
#           3.82400000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S3_D2 850',
#   'scanno': 6,
#   'logno': 6},
#  {'loc': array([-1.56422671e-02,  9.87690203e-02,  1.01244447e-05, -0.00000000e+00,
#           1.00000000e-01,  1.00000000e-05, -3.09000000e-02,  9.51100000e-02,
#           1.00000000e-05,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S4_D1 760',
#   'scanno': 7,
#   'logno': 7},
#  {'loc': array([-1.56422671e-02,  9.87690203e-02,  1.01244447e-05, -0.00000000e+00,
#           1.00000000e-01,  1.00000000e-05, -3.09000000e-02,  9.51100000e-02,
#           1.00000000e-05,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S4_D1 850',
#   'scanno': 8,
#   'logno': 8},
#  {'loc': array([-0.00000000e+00,  9.80786108e-02,  1.95086160e-02, -0.00000000e+00,
#           1.00000000e-01,  1.00000000e-05, -0.00000000e+00,  9.23000000e-02,
#           3.82400000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S4_D2 760',
#   'scanno': 9,
#   'logno': 9},
#  {'loc': array([-0.00000000e+00,  9.80786108e-02,  1.95086160e-02, -0.00000000e+00,
#           1.00000000e-01,  1.00000000e-05, -0.00000000e+00,  9.23000000e-02,
#           3.82400000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S4_D2 850',
#   'scanno': 10,
#   'logno': 10},
#  {'loc': array([ 1.56472054e-02,  9.87682385e-02,  5.06218228e-06, -0.00000000e+00,
#           1.00000000e-01,  1.00000000e-05,  3.09100000e-02,  9.51100000e-02,
#           0.00000000e+00,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S4_D3 760',
#   'scanno': 11,
#   'logno': 11},
#  {'loc': array([ 1.56472054e-02,  9.87682385e-02,  5.06218228e-06, -0.00000000e+00,
#           1.00000000e-01,  1.00000000e-05,  3.09100000e-02,  9.51100000e-02,
#           0.00000000e+00,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S4_D3 850',
#   'scanno': 12,
#   'logno': 12},
#  {'loc': array([ 1.80922060e-02,  9.24163938e-02,  3.36434577e-02,  3.55300000e-02,
#           8.91900000e-02,  2.78300000e-02, -0.00000000e+00,  9.23000000e-02,
#           3.82400000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S5_D2 760',
#   'scanno': 13,
#   'logno': 13},
#  {'loc': array([ 1.80922060e-02,  9.24163938e-02,  3.36434577e-02,  3.55300000e-02,
#           8.91900000e-02,  2.78300000e-02, -0.00000000e+00,  9.23000000e-02,
#           3.82400000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S5_D2 850',
#   'scanno': 14,
#   'logno': 14},
#  {'loc': array([3.35764285e-02, 9.31387081e-02, 1.40642987e-02, 3.55300000e-02,
#          8.91900000e-02, 2.78300000e-02, 3.09100000e-02, 9.51100000e-02,
#          0.00000000e+00, 7.60000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S5_D3 760',
#   'scanno': 15,
#   'logno': 15},
#  {'loc': array([3.35764285e-02, 9.31387081e-02, 1.40642987e-02, 3.55300000e-02,
#          8.91900000e-02, 2.78300000e-02, 3.09100000e-02, 9.51100000e-02,
#          0.00000000e+00, 8.50000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S5_D3 850',
#   'scanno': 16,
#   'logno': 16},
#  {'loc': array([4.54024360e-02, 8.90989271e-02, 0.00000000e+00, 5.87800000e-02,
#          8.09000000e-02, 0.00000000e+00, 3.09100000e-02, 9.51100000e-02,
#          0.00000000e+00, 7.60000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S6_D3 760',
#   'scanno': 17,
#   'logno': 17},
#  {'loc': array([4.54024360e-02, 8.90989271e-02, 0.00000000e+00, 5.87800000e-02,
#          8.09000000e-02, 0.00000000e+00, 3.09100000e-02, 9.51100000e-02,
#          0.00000000e+00, 8.50000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S6_D3 850',
#   'scanno': 18,
#   'logno': 18},
#  {'loc': array([-0.00000000e+00, -9.80795866e-02,  1.95037098e-02, -0.00000000e+00,
#          -1.00000000e-01,  0.00000000e+00, -0.00000000e+00, -9.23000000e-02,
#           3.82400000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S7_D4 760',
#   'scanno': 19,
#   'logno': 19},
#  {'loc': array([-0.00000000e+00, -9.80795866e-02,  1.95037098e-02, -0.00000000e+00,
#          -1.00000000e-01,  0.00000000e+00, -0.00000000e+00, -9.23000000e-02,
#           3.82400000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S7_D4 850',
#   'scanno': 20,
#   'logno': 20},
#  {'loc': array([-1.56422672e-02, -9.87690208e-02,  0.00000000e+00, -0.00000000e+00,
#          -1.00000000e-01,  0.00000000e+00, -3.09000000e-02, -9.51100000e-02,
#           0.00000000e+00,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S7_D6 760',
#   'scanno': 21,
#   'logno': 21},
#  {'loc': array([-1.56422672e-02, -9.87690208e-02,  0.00000000e+00, -0.00000000e+00,
#          -1.00000000e-01,  0.00000000e+00, -3.09000000e-02, -9.51100000e-02,
#           0.00000000e+00,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S7_D6 850',
#   'scanno': 22,
#   'logno': 22},
#  {'loc': array([ 1.56422672e-02, -9.87690208e-02,  0.00000000e+00, -0.00000000e+00,
#          -1.00000000e-01,  0.00000000e+00,  3.09000000e-02, -9.51100000e-02,
#           0.00000000e+00,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S7_D7 760',
#   'scanno': 23,
#   'logno': 23},
#  {'loc': array([ 1.56422672e-02, -9.87690208e-02,  0.00000000e+00, -0.00000000e+00,
#          -1.00000000e-01,  0.00000000e+00,  3.09000000e-02, -9.51100000e-02,
#           0.00000000e+00,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S7_D7 850',
#   'scanno': 24,
#   'logno': 24},
#  {'loc': array([-9.11263370e-02, -1.71144288e-02,  3.74578035e-02, -9.23700000e-02,
#           1.00000000e-05,  3.82600000e-02, -8.71200000e-02, -3.37200000e-02,
#           3.55200000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S9_D5 760',
#   'scanno': 25,
#   'logno': 25},
#  {'loc': array([-9.11263370e-02, -1.71144288e-02,  3.74578035e-02, -9.23700000e-02,
#           1.00000000e-05,  3.82600000e-02, -8.71200000e-02, -3.37200000e-02,
#           3.55200000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S9_D5 850',
#   'scanno': 26,
#   'logno': 26},
#  {'loc': array([-9.11265755e-02,  1.71325680e-02,  3.74489298e-02, -9.23700000e-02,
#           1.00000000e-05,  3.82600000e-02, -8.70900000e-02,  3.37300000e-02,
#           3.54900000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S9_D9 760',
#   'scanno': 27,
#   'logno': 27},
#  {'loc': array([-9.11265755e-02,  1.71325680e-02,  3.74489298e-02, -9.23700000e-02,
#           1.00000000e-05,  3.82600000e-02, -8.70900000e-02,  3.37300000e-02,
#           3.54900000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S9_D9 850',
#   'scanno': 28,
#   'logno': 28},
#  {'loc': array([-8.31500620e-02,  1.02005842e-05,  5.55523815e-02, -9.23700000e-02,
#           1.00000000e-05,  3.82600000e-02, -7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S9_D10 760',
#   'scanno': 29,
#   'logno': 29},
#  {'loc': array([-8.31500620e-02,  1.02005842e-05,  5.55523815e-02, -9.23700000e-02,
#           1.00000000e-05,  3.82600000e-02, -7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S9_D10 850',
#   'scanno': 30,
#   'logno': 30},
#  {'loc': array([-7.80929869e-02,  3.55430712e-02,  5.13631726e-02, -6.63800000e-02,
#           3.61200000e-02,  6.54500000e-02, -8.70900000e-02,  3.37300000e-02,
#           3.54900000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S10_D9 760',
#   'scanno': 31,
#   'logno': 31},
#  {'loc': array([-7.80929869e-02,  3.55430712e-02,  5.13631726e-02, -6.63800000e-02,
#           3.61200000e-02,  6.54500000e-02, -8.70900000e-02,  3.37300000e-02,
#           3.54900000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S10_D9 850',
#   'scanno': 32,
#   'logno': 32},
#  {'loc': array([-6.97413425e-02,  1.83870016e-02,  6.92680541e-02, -6.63800000e-02,
#           3.61200000e-02,  6.54500000e-02, -7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S10_D10 760',
#   'scanno': 33,
#   'logno': 33},
#  {'loc': array([-6.97413425e-02,  1.83870016e-02,  6.92680541e-02, -6.63800000e-02,
#           3.61200000e-02,  6.54500000e-02, -7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S10_D10 850',
#   'scanno': 34,
#   'logno': 34},
#  {'loc': array([-5.19973252e-02,  3.75618216e-02,  7.67162807e-02, -6.63800000e-02,
#           3.61200000e-02,  6.54500000e-02, -3.58100000e-02,  3.77000000e-02,
#           8.53200000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S10_D11 760',
#   'scanno': 35,
#   'logno': 35},
#  {'loc': array([-5.19973252e-02,  3.75618216e-02,  7.67162807e-02, -6.63800000e-02,
#           3.61200000e-02,  6.54500000e-02, -3.58100000e-02,  3.77000000e-02,
#           8.53200000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S10_D11 850',
#   'scanno': 36,
#   'logno': 36},
#  {'loc': array([-7.80965939e-02, -3.55243580e-02,  5.13706337e-02, -6.63500000e-02,
#          -3.60900000e-02,  6.54300000e-02, -8.71200000e-02, -3.37200000e-02,
#           3.55200000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S11_D5 760',
#   'scanno': 37,
#   'logno': 37},
#  {'loc': array([-7.80965939e-02, -3.55243580e-02,  5.13706337e-02, -6.63500000e-02,
#          -3.60900000e-02,  6.54300000e-02, -8.71200000e-02, -3.37200000e-02,
#           3.55200000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S11_D5 850',
#   'scanno': 38,
#   'logno': 38},
#  {'loc': array([-6.97416793e-02, -1.83656652e-02,  6.92733752e-02, -6.63500000e-02,
#          -3.60900000e-02,  6.54300000e-02, -7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S11_D10 760',
#   'scanno': 39,
#   'logno': 39},
#  {'loc': array([-6.97416793e-02, -1.83656652e-02,  6.92733752e-02, -6.63500000e-02,
#          -3.60900000e-02,  6.54300000e-02, -7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S11_D10 850',
#   'scanno': 40,
#   'logno': 40},
#  {'loc': array([-5.19884336e-02, -3.75395679e-02,  7.67331976e-02, -6.63500000e-02,
#          -3.60900000e-02,  6.54300000e-02, -3.58000000e-02, -3.76700000e-02,
#           8.53400000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S11_D12 760',
#   'scanno': 41,
#   'logno': 41},
#  {'loc': array([-5.19884336e-02, -3.75395679e-02,  7.67331976e-02, -6.63500000e-02,
#          -3.60900000e-02,  6.54300000e-02, -3.58000000e-02, -3.76700000e-02,
#           8.53400000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S11_D12 850',
#   'scanno': 42,
#   'logno': 42},
#  {'loc': array([-5.55594660e-02,  1.53056380e-05,  8.31453276e-02, -3.82400000e-02,
#           2.00000000e-05,  9.23100000e-02, -7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S12_D10 760',
#   'scanno': 43,
#   'logno': 43},
#  {'loc': array([-5.55594660e-02,  1.53056380e-05,  8.31453276e-02, -3.82400000e-02,
#           2.00000000e-05,  9.23100000e-02, -7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S12_D10 850',
#   'scanno': 44,
#   'logno': 44},
#  {'loc': array([-3.77596732e-02,  1.92342319e-02,  9.05773228e-02, -3.82400000e-02,
#           2.00000000e-05,  9.23100000e-02, -3.58100000e-02,  3.77000000e-02,
#           8.53200000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S12_D11 760',
#   'scanno': 45,
#   'logno': 45},
#  {'loc': array([-3.77596732e-02,  1.92342319e-02,  9.05773228e-02, -3.82400000e-02,
#           2.00000000e-05,  9.23100000e-02, -3.58100000e-02,  3.77000000e-02,
#           8.53200000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S12_D11 850',
#   'scanno': 46,
#   'logno': 46},
#  {'loc': array([-3.77544028e-02, -1.91984504e-02,  9.05871104e-02, -3.82400000e-02,
#           2.00000000e-05,  9.23100000e-02, -3.58000000e-02, -3.76700000e-02,
#           8.53400000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S12_D12 760',
#   'scanno': 47,
#   'logno': 47},
#  {'loc': array([-3.77544028e-02, -1.91984504e-02,  9.05871104e-02, -3.82400000e-02,
#           2.00000000e-05,  9.23100000e-02, -3.58000000e-02, -3.76700000e-02,
#           8.53400000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S12_D12 850',
#   'scanno': 48,
#   'logno': 48},
#  {'loc': array([3.77600435e-02, 1.92293213e-02, 9.05782111e-02, 3.82400000e-02,
#          1.00000000e-05, 9.23100000e-02, 3.58100000e-02, 3.77000000e-02,
#          8.53200000e-02, 7.60000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S13_D13 760',
#   'scanno': 49,
#   'logno': 49},
#  {'loc': array([3.77600435e-02, 1.92293213e-02, 9.05782111e-02, 3.82400000e-02,
#          1.00000000e-05, 9.23100000e-02, 3.58100000e-02, 3.77000000e-02,
#          8.53200000e-02, 8.50000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S13_D13 850',
#   'scanno': 50,
#   'logno': 50},
#  {'loc': array([ 3.77540331e-02, -1.92033615e-02,  9.05862235e-02,  3.82400000e-02,
#           1.00000000e-05,  9.23100000e-02,  3.58000000e-02, -3.76700000e-02,
#           8.53400000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S13_D14 760',
#   'scanno': 51,
#   'logno': 51},
#  {'loc': array([ 3.77540331e-02, -1.92033615e-02,  9.05862235e-02,  3.82400000e-02,
#           1.00000000e-05,  9.23100000e-02,  3.58000000e-02, -3.76700000e-02,
#           8.53400000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S13_D14 850',
#   'scanno': 52,
#   'logno': 52},
#  {'loc': array([5.55594664e-02, 1.02037587e-05, 8.31453281e-02, 3.82400000e-02,
#          1.00000000e-05, 9.23100000e-02, 7.06600000e-02, 1.00000000e-05,
#          7.06600000e-02, 7.60000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S13_D15 760',
#   'scanno': 53,
#   'logno': 53},
#  {'loc': array([5.55594664e-02, 1.02037587e-05, 8.31453281e-02, 3.82400000e-02,
#          1.00000000e-05, 9.23100000e-02, 7.06600000e-02, 1.00000000e-05,
#          7.06600000e-02, 8.50000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S13_D15 850',
#   'scanno': 54,
#   'logno': 54},
#  {'loc': array([5.19973252e-02, 3.75618216e-02, 7.67162807e-02, 6.63800000e-02,
#          3.61200000e-02, 6.54500000e-02, 3.58100000e-02, 3.77000000e-02,
#          8.53200000e-02, 7.60000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S14_D13 760',
#   'scanno': 55,
#   'logno': 55},
#  {'loc': array([5.19973252e-02, 3.75618216e-02, 7.67162807e-02, 6.63800000e-02,
#          3.61200000e-02, 6.54500000e-02, 3.58100000e-02, 3.77000000e-02,
#          8.53200000e-02, 8.50000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S14_D13 850',
#   'scanno': 56,
#   'logno': 56},
#  {'loc': array([6.97413425e-02, 1.83870016e-02, 6.92680541e-02, 6.63800000e-02,
#          3.61200000e-02, 6.54500000e-02, 7.06600000e-02, 1.00000000e-05,
#          7.06600000e-02, 7.60000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S14_D15 760',
#   'scanno': 57,
#   'logno': 57},
#  {'loc': array([6.97413425e-02, 1.83870016e-02, 6.92680541e-02, 6.63800000e-02,
#          3.61200000e-02, 6.54500000e-02, 7.06600000e-02, 1.00000000e-05,
#          7.06600000e-02, 8.50000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S14_D15 850',
#   'scanno': 58,
#   'logno': 58},
#  {'loc': array([7.80929869e-02, 3.55430712e-02, 5.13631726e-02, 6.63800000e-02,
#          3.61200000e-02, 6.54500000e-02, 8.70900000e-02, 3.37300000e-02,
#          3.54900000e-02, 7.60000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S14_D16 760',
#   'scanno': 59,
#   'logno': 59},
#  {'loc': array([7.80929869e-02, 3.55430712e-02, 5.13631726e-02, 6.63800000e-02,
#          3.61200000e-02, 6.54500000e-02, 8.70900000e-02, 3.37300000e-02,
#          3.54900000e-02, 8.50000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S14_D16 850',
#   'scanno': 60,
#   'logno': 60},
#  {'loc': array([ 7.80980056e-02, -3.55199113e-02,  5.13715623e-02,  6.63500000e-02,
#          -3.60800000e-02,  6.54300000e-02,  8.71200000e-02, -3.37200000e-02,
#           3.55200000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S15_D8 760',
#   'scanno': 61,
#   'logno': 61},
#  {'loc': array([ 7.80980056e-02, -3.55199113e-02,  5.13715623e-02,  6.63500000e-02,
#          -3.60800000e-02,  6.54300000e-02,  8.71200000e-02, -3.37200000e-02,
#           3.55200000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S15_D8 850',
#   'scanno': 62,
#   'logno': 62},
#  {'loc': array([ 5.19894268e-02, -3.75351956e-02,  7.67346636e-02,  6.63500000e-02,
#          -3.60800000e-02,  6.54300000e-02,  3.58000000e-02, -3.76700000e-02,
#           8.53400000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S15_D14 760',
#   'scanno': 63,
#   'logno': 63},
#  {'loc': array([ 5.19894268e-02, -3.75351956e-02,  7.67346636e-02,  6.63500000e-02,
#          -3.60800000e-02,  6.54300000e-02,  3.58000000e-02, -3.76700000e-02,
#           8.53400000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S15_D14 850',
#   'scanno': 64,
#   'logno': 64},
#  {'loc': array([ 6.97423312e-02, -1.83607466e-02,  6.92740227e-02,  6.63500000e-02,
#          -3.60800000e-02,  6.54300000e-02,  7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S15_D15 760',
#   'scanno': 65,
#   'logno': 65},
#  {'loc': array([ 6.97423312e-02, -1.83607466e-02,  6.92740227e-02,  6.63500000e-02,
#          -3.60800000e-02,  6.54300000e-02,  7.06600000e-02,  1.00000000e-05,
#           7.06600000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S15_D15 850',
#   'scanno': 66,
#   'logno': 66},
#  {'loc': array([ 9.11263370e-02, -1.71144288e-02,  3.74578035e-02,  9.23700000e-02,
#           1.00000000e-05,  3.82600000e-02,  8.71200000e-02, -3.37200000e-02,
#           3.55200000e-02,  7.60000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S16_D8 760',
#   'scanno': 67,
#   'logno': 67},
#  {'loc': array([ 9.11263370e-02, -1.71144288e-02,  3.74578035e-02,  9.23700000e-02,
#           1.00000000e-05,  3.82600000e-02,  8.71200000e-02, -3.37200000e-02,
#           3.55200000e-02,  8.50000000e+02,             nan,             nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S16_D8 850',
#   'scanno': 68,
#   'logno': 68},
#  {'loc': array([8.31500620e-02, 1.02005842e-05, 5.55523815e-02, 9.23700000e-02,
#          1.00000000e-05, 3.82600000e-02, 7.06600000e-02, 1.00000000e-05,
#          7.06600000e-02, 7.60000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S16_D15 760',
#   'scanno': 69,
#   'logno': 69},
#  {'loc': array([8.31500620e-02, 1.02005842e-05, 5.55523815e-02, 9.23700000e-02,
#          1.00000000e-05, 3.82600000e-02, 7.06600000e-02, 1.00000000e-05,
#          7.06600000e-02, 8.50000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S16_D15 850',
#   'scanno': 70,
#   'logno': 70},
#  {'loc': array([9.11265755e-02, 1.71325680e-02, 3.74489298e-02, 9.23700000e-02,
#          1.00000000e-05, 3.82600000e-02, 8.70900000e-02, 3.37300000e-02,
#          3.54900000e-02, 7.60000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S16_D16 760',
#   'scanno': 71,
#   'logno': 71},
#  {'loc': array([9.11265755e-02, 1.71325680e-02, 3.74489298e-02, 9.23700000e-02,
#          1.00000000e-05, 3.82600000e-02, 8.70900000e-02, 3.37300000e-02,
#          3.54900000e-02, 8.50000000e+02,            nan,            nan]),
#   'unit_mul': 0,
#   'range': 1.0,
#   'cal': 1.0,
#   'kind': 1100 (FIFFV_FNIRS_CH),
#   'coil_type': 302 (FIFFV_COIL_FNIRS_RAW),
#   'unit': 107 (FIFF_UNIT_V),
#   'coord_frame': 0 (FIFFV_COORD_UNKNOWN),
#   'ch_name': 'S16_D16 850',
#   'scanno': 72,
#   'logno': 72}]

# %%
#Data divided in three sessions
nirs_matcnt = {}
x=0

for i in range(3):
    nirs_matcnt["session{0}".format(i+1)] = pd.DataFrame([[row.flat[0] for row in line] for line
                                                        in nirs_matlab_files['cnt'][0][x]['x'][0][0]],
                                                        columns=nirs_channels)
    x+=2

# %%
#Reorder columns

for i in range(3): 
    nirs_matcnt["session{0}".format(i+1)]=nirs_matcnt["session{0}".format(i+1)][['AF7Fp1lowWL','AF7Fp1highWL','AF3Fp1lowWL',
                                                                     'AF3Fp1highWL','AF3AFzlowWL','AF3AFzhighWL',
                                                                     'FpzFp1lowWL','FpzFp1highWL','FpzAFzlowWL',
                                                                     'FpzAFzhighWL','FpzFp2lowWL','FpzFp2highWL', 
                                                                     'AF4AFzlowWL','AF4AFzhighWL','AF4Fp2lowWL',
                                                                     'AF4Fp2highWL','AF8Fp2lowWL','AF8Fp2highWL',
                                                                     'OzPOzlowWL','OzPOzhighWL','OzO1lowWL',
                                                                     'OzO1highWL','OzO2lowWL','OzO2highWL',
                                                                     'C5CP5lowWL','C5CP5highWL','C5FC5lowWL',
                                                                     'C5FC5highWL','C5C3lowWL','C5C3highWL',
                                                                     'FC3FC5lowWL','FC3FC5highWL','FC3C3lowWL',
                                                                     'FC3C3highWL','FC3FC1lowWL','FC3FC1highWL',
                                                                     'CP3CP5lowWL','CP3CP5highWL','CP3C3lowWL',
                                                                     'CP3C3highWL','CP3CP1lowWL','CP3CP1highWL',
                                                                     'C1C3lowWL','C1C3highWL','C1FC1lowWL','C1FC1highWL',
                                                                     'C1CP1lowWL','C1CP1highWL','C2FC2lowWL','C2FC2highWL',
                                                                     'C2CP2lowWL','C2CP2highWL','C2C4lowWL','C2C4highWL',
                                                                     'FC4FC2lowWL','FC4FC2highWL','FC4C4lowWL','FC4C4highWL',
                                                                     'FC4FC6lowWL','FC4FC6highWL','CP4CP6lowWL','CP4CP6highWL',
                                                                     'CP4CP2lowWL','CP4CP2highWL','CP4C4lowWL','CP4C4highWL',
                                                                     'C6CP6lowWL','C6CP6highWL','C6C4lowWL','C6C4highWL',
                                                                        'C6FC6lowWL','C6FC6highWL']]

# %%
nirs_matcnt["session1"]
# Out:
#       AF7Fp1lowWL  AF7Fp1highWL  AF3Fp1lowWL  AF3Fp1highWL  AF3AFzlowWL  \
# 0        1.006429      0.748526     0.608247      0.506704     0.142602
# 1        1.153509      0.857362     0.696988      0.580308     0.164340
# 2        1.098856      0.816095     0.663754      0.553567     0.154130
# 3        1.135370      0.844668     0.686435      0.573386     0.158730
# 4        1.117435      0.832791     0.677813      0.566625     0.158940
# ...           ...           ...          ...           ...          ...
# 7215     1.042625      0.732012     0.652768      0.532782     0.160487
# 7216     1.032066      0.725818     0.645907      0.527151     0.159684
# 7217     1.047764      0.737006     0.657484      0.536938     0.162735
# 7218     1.019922      0.718458     0.640603      0.524346     0.155258
# 7219     1.076661      0.759664     0.677014      0.556104     0.166299
#
#       AF3AFzhighWL  FpzFp1lowWL  FpzFp1highWL  FpzAFzlowWL  FpzAFzhighWL  ...  \
# 0         0.233589     0.208507      0.141471     0.097752      0.109805  ...
# 1         0.268344     0.239259      0.162230     0.112247      0.125650  ...
# 2         0.253775     0.228382      0.154939     0.107175      0.120099  ...
# 3         0.262853     0.236180      0.160652     0.110557      0.124386  ...
# 4         0.260976     0.233475      0.159126     0.109263      0.123218  ...
# ...            ...          ...           ...          ...           ...  ...
# 7215      0.264170     0.226337      0.147898     0.106448      0.115790  ...
# 7216      0.261079     0.223375      0.145926     0.105118      0.114393  ...
# 7217      0.266833     0.227558      0.148701     0.107117      0.116477  ...
# 7218      0.259603     0.222172      0.145384     0.104608      0.113498  ...
# 7219      0.275221     0.235387      0.154543     0.110558      0.120902  ...
#
#       CP4CP2lowWL  CP4CP2highWL  CP4C4lowWL  CP4C4highWL  C6CP6lowWL  \
# 0        0.059968      0.123639    0.346404     0.863722    0.132603
# 1        0.068468      0.141769    0.394039     0.982132    0.151674
# 2        0.065238      0.136375    0.363680     0.944856    0.147260
# 3        0.068409      0.142154    0.382603     0.983003    0.150859
# 4        0.066782      0.139781    0.387146     0.985354    0.149075
# ...           ...           ...         ...          ...         ...
# 7215     0.065047      0.139924    0.368483     1.012994    0.144276
# 7216     0.063742      0.137291    0.376235     1.003432    0.143257
# 7217     0.065762      0.139979    0.380380     1.024563    0.144432
# 7218     0.063645      0.137928    0.369550     0.997399    0.142159
# 7219     0.067483      0.145733    0.386842     1.060199    0.149818
#
#       C6CP6highWL  C6C4lowWL  C6C4highWL  C6FC6lowWL  C6FC6highWL
# 0        0.239508   0.081373    0.197045    0.459112     0.887477
# 1        0.277411   0.092577    0.225627    0.528415     1.020472
# 2        0.265530   0.088456    0.215952    0.505602     0.978382
# 3        0.273750   0.091774    0.221624    0.522335     1.013728
# 4        0.273948   0.090639    0.221277    0.517282     1.008027
# ...           ...        ...         ...         ...          ...
# 7215     0.261161   0.088002    0.218355    0.501845     0.977464
# 7216     0.258973   0.086992    0.215844    0.494463     0.967496
# 7217     0.265166   0.088505    0.220804    0.507042     0.989000
# 7218     0.259792   0.087020    0.215928    0.494144     0.966446
# 7219     0.274004   0.092184    0.229618    0.522260     1.027720
#
# [7220 rows x 72 columns]

# %%
nirs_raw = {}

#Create raw objects with the new channel names
nirs_raw["session1"] = mne.io.RawArray(nirs_matcnt["session1"].T, info)
nirs_raw["session2"] = mne.io.RawArray(nirs_matcnt["session2"].T, info)
nirs_raw["session3"] = mne.io.RawArray(nirs_matcnt["session3"].T, info)
# Out:
# Creating RawArray with float64 data, n_channels=72, n_times=7220
#     Range : 0 ... 7219 =      0.000 ...   721.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=72, n_times=7204
#     Range : 0 ... 7203 =      0.000 ...   720.300 secs
# Ready.
# Creating RawArray with float64 data, n_channels=72, n_times=7216
#     Range : 0 ... 7215 =      0.000 ...   721.500 secs
# Ready.

# %%
raw_od1 = mne.preprocessing.nirs.optical_density(nirs_raw["session1"])
raw_od2 = mne.preprocessing.nirs.optical_density(nirs_raw["session2"])
raw_od3 = mne.preprocessing.nirs.optical_density(nirs_raw["session3"])

raw_od1.plot(n_channels=len(raw_od1.ch_names),
            duration=500, show_scrollbars=False)
raw_od2.plot(n_channels=len(raw_od2.ch_names),
            duration=500, show_scrollbars=False)
raw_od3.plot(n_channels=len(raw_od3.ch_names),
            duration=500, show_scrollbars=False)

# %% [markdown]
# ## Evaluating the quality of the data

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import compress

sci = mne.preprocessing.nirs.scalp_coupling_index(raw_od1)
fig, ax = plt.subplots()
ax.hist(sci)
ax.set(xlabel='Scalp Coupling Index', ylabel='Count', xlim=[0, 1])
# Out:
# [Text(0, 0.5, 'Count'), (0, 1), Text(0.5, 0, 'Scalp Coupling Index')]

# %%
raw1_haemo = mne.preprocessing.nirs.beer_lambert_law(raw_od1)
raw2_haemo = mne.preprocessing.nirs.beer_lambert_law(raw_od2)
raw3_haemo = mne.preprocessing.nirs.beer_lambert_law(raw_od3)

raw1_haemo.plot(n_channels=len(raw1_haemo.ch_names),
               duration=500, show_scrollbars=False)
raw2_haemo.plot(n_channels=len(raw2_haemo.ch_names),
               duration=500, show_scrollbars=False)
raw3_haemo.plot(n_channels=len(raw3_haemo.ch_names),
               duration=500, show_scrollbars=False)

# %%
raw1_haemo.info

# %%
#Band-pass HbO and HbR from 0.01Hz to 0.1 Hz
fig = raw1_haemo.plot_psd(average=True)
fig.suptitle('Before filtering', weight='bold', size='x-large')
fig.subplots_adjust(top=0.88)
raw1_haemo = raw1_haemo.filter(0.01, 0.1, h_trans_bandwidth='auto',
                             l_trans_bandwidth='auto')
raw2_haemo = raw2_haemo.filter(0.01, 0.1, h_trans_bandwidth='auto',
                             l_trans_bandwidth='auto')
raw3_haemo = raw3_haemo.filter(0.01, 0.1, h_trans_bandwidth='auto',
                             l_trans_bandwidth='auto')
fig = raw1_haemo.plot_psd(average=True)
fig.suptitle('After filtering', weight='bold', size='x-large')
fig.subplots_adjust(top=0.88)
# Out:
# Effective window size : 204.800 (s)
# Effective window size : 204.800 (s)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.01 - 0.1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.01
# - Lower transition bandwidth: 0.01 Hz (-6 dB cutoff frequency: 0.01 Hz)
# - Upper passband edge: 0.10 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 1.10 Hz)
# - Filter length: 3301 samples (330.100 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.01 - 0.1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.01
# - Lower transition bandwidth: 0.01 Hz (-6 dB cutoff frequency: 0.01 Hz)
# - Upper passband edge: 0.10 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 1.10 Hz)
# - Filter length: 3301 samples (330.100 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.01 - 0.1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.01
# - Lower transition bandwidth: 0.01 Hz (-6 dB cutoff frequency: 0.01 Hz)
# - Upper passband edge: 0.10 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 1.10 Hz)
# - Filter length: 3301 samples (330.100 sec)
#
# Effective window size : 204.800 (s)
# Effective window size : 204.800 (s)

# %%
#Extracting Epochs
filename = r"C:\Users\bio86\Downloads\NIRS_01-29\subject 19\mrk.mat"
matlab_mrk = loadmat(filename)
nirs_events1=np.transpose(np.vstack(
        ((matlab_mrk['mrk'][0][0][0][0][0][0])/100,
         np.vstack((np.zeros(20),np.transpose(matlab_mrk['mrk'][0][0][0][0][1][0][0][0])[0])))))
nirs_events2=np.transpose(np.vstack(
        ((matlab_mrk['mrk'][0][2][0][0][0][0])/100,
         np.vstack((np.zeros(20),np.transpose(matlab_mrk['mrk'][0][2][0][0][1][0][0][0])[0])))))
nirs_events3=np.transpose(np.vstack(
        ((matlab_mrk['mrk'][0][4][0][0][0][0])/100,
         np.vstack((np.zeros(20),np.transpose(matlab_mrk['mrk'][0][4][0][0][1][0][0][0])[0])))))

# %%
#Information about the events
event_id = dict(LMI=1, RMI=2)

# %%
#Create epochs objects and perform Baseline correction
epochs1 = mne.Epochs(raw1_haemo, events=nirs_events1.astype(int),tmin=-5,tmax=2,
                     event_id=event_id,proj=True, baseline=(-5, 2),
                     preload=True,detrend=None, verbose=True)
epochs2 = mne.Epochs(raw1_haemo,  events=nirs_events2.astype(int),tmin=-5,tmax=2,
                     event_id=event_id,proj=True, baseline=(-5, 2),
                     preload=True,detrend=None, verbose=True)
epochs3 = mne.Epochs(raw1_haemo, events=nirs_events3.astype(int),tmin=-5,tmax=2,
                     event_id=event_id,proj=True, baseline=(-5, 2),
                     preload=True,detrend=None, verbose=True)
# Out:
# 20 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 20 events and 71 original time points ...
# 0 bad epochs dropped
# 20 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 20 events and 71 original time points ...
# 0 bad epochs dropped
# 20 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 20 events and 71 original time points ...
# 0 bad epochs dropped

# %%
epochs1.plot()

# %%
#Concatenate raws
epochs = mne.concatenate_epochs((epochs1,epochs2,epochs3),add_offset=True)
# Out:
# 60 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 bad epochs dropped

# %% [markdown]
# ## View consistency of responses across trials

# %%
epochs['LMI'].plot_image(combine='mean', vmin=-30, vmax=30,
                             ts_args=dict(ylim=dict(hbo=[-15, 15],
                                                    hbr=[-15, 15])))
# Out:
# 30 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# 0 bad epochs dropped
# 30 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# 0 bad epochs dropped
# combining channels using "mean"
# combining channels using "mean"
# [<Figure size 432x288 with 3 Axes>, <Figure size 432x288 with 3 Axes>]

# %%
epochs['RMI'].plot_image(combine='mean', vmin=-30, vmax=30,
                             ts_args=dict(ylim=dict(hbo=[-15, 15],
                                                    hbr=[-15, 15])))
# Out:
# 30 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# 0 bad epochs dropped
# 30 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# 0 bad epochs dropped
# combining channels using "mean"
# combining channels using "mean"
# [<Figure size 432x288 with 3 Axes>, <Figure size 432x288 with 3 Axes>]

# %% [markdown]
# ## View consistency of responses across channels

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 6))
clims = dict(hbo=[-20, 20], hbr=[-20, 20])
epochs['LMI'].average().plot_image(axes=axes[:, 0], clim=clims)
epochs['RMI'].average().plot_image(axes=axes[:, 1], clim=clims)
for column, condition in enumerate(['Control', 'Tapping']):
    for ax in axes[:, column]:
        ax.set_title('{}: {}'.format(condition, ax.get_title()))

# %% [markdown]
# ## Plot standard fNIRS response image

# %%
evoked_dict = {'LMI/HbO': epochs['LMI'].average(picks='hbo'),
               'LMI/HbR': epochs['LMI'].average(picks='hbr'),
               'RMI/HbO': epochs['RMI'].average(picks='hbo'),
               'RMI/HbR': epochs['RMI'].average(picks='hbr')}

# Rename channels until the encoding of frequency in ch_name is fixed
for condition in evoked_dict:
    evoked_dict[condition].rename_channels(lambda x: x[:-4])

color_dict = dict(HbO='#AA3377', HbR='b')
styles_dict = dict(LMI=dict(linestyle='dashed'))

mne.viz.plot_compare_evokeds(evoked_dict, combine="mean", ci=0.95,
                             colors=color_dict, styles=styles_dict)
# Out:
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# [<Figure size 576x432 with 1 Axes>]

# %% [markdown]
# ## View topographic representation of activity

# %%
times = np.arange(-3.5, 2, 2.0)
topomap_args = dict(extrapolate='local')
epochs['LMI'].average(picks='hbo').plot_joint(
    times=times, topomap_args=topomap_args)

# %% [markdown]
# ## Compare tapping of left and right hands

# %%
times = np.arange(-5.0, 2.0, 2.0)
epochs['LMI'].average(picks='hbo').plot_topomap(
    times=times, **topomap_args)
epochs['RMI'].average(picks='hbo').plot_topomap(
    times=times, **topomap_args)

# %%
times = np.arange(-5.0, 2.0, 2.0)
epochs['LMI'].average(picks='hbr').plot_topomap(
    times=times, **topomap_args)
epochs['RMI'].average(picks='hbr').plot_topomap(
    times=times, **topomap_args)

# %%
#Comparison

fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(9, 5),
                         gridspec_kw=dict(width_ratios=[1, 1, 1, 0.1]))
vmin, vmax, ts = -5, 2, 2.0

evoked_left = epochs['LMI'].average()
evoked_right = epochs['RMI'].average()

evoked_left.plot_topomap(ch_type='hbo', times=ts, axes=axes[0, 0],
                         vmin=vmin, vmax=vmax, colorbar=False,
                         **topomap_args)
evoked_left.plot_topomap(ch_type='hbr', times=ts, axes=axes[1, 0],
                         vmin=vmin, vmax=vmax, colorbar=False,
                         **topomap_args)
evoked_right.plot_topomap(ch_type='hbo', times=ts, axes=axes[0, 1],
                          vmin=vmin, vmax=vmax, colorbar=False,
                          **topomap_args)
evoked_right.plot_topomap(ch_type='hbr', times=ts, axes=axes[1, 1],
                          vmin=vmin, vmax=vmax, colorbar=False,
                          **topomap_args)

evoked_diff = mne.combine_evoked([evoked_left, evoked_right], weights=[1, -1])

evoked_diff.plot_topomap(ch_type='hbo', times=ts, axes=axes[0, 2:],
                         vmin=vmin, vmax=vmax, colorbar=True,
                         **topomap_args)
evoked_diff.plot_topomap(ch_type='hbr', times=ts, axes=axes[1, 2:],
                         vmin=vmin, vmax=vmax, colorbar=True,
                         **topomap_args)

for column, condition in enumerate(
        ['LMI', 'RMI', 'Left-Right']):
    for row, chroma in enumerate(['HbO', 'HbR']):
        axes[row, column].set_title('{}: {}'.format(chroma, condition))
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-54-5e257c54dce8> in <module>
#      25 evoked_diff.plot_topomap(ch_type='hbo', times=ts, axes=axes[0, 2:],
#      26                          vmin=vmin, vmax=vmax, colorbar=True,
# ---> 27                          **topomap_args)
#      28 evoked_diff.plot_topomap(ch_type='hbr', times=ts, axes=axes[1, 2:],
#      29                          vmin=vmin, vmax=vmax, colorbar=True,
#
# ~\anaconda3\lib\site-packages\mne\evoked.py in plot_topomap(self, times, ch_type, layout, vmin, vmax, cmap, sensors, colorbar, scalings, units, res, size, cbar_fmt, time_unit, time_format, proj, show, show_names, title, mask, mask_params, outlines, contours, image_interp, average, head_pos, axes, extrapolate, sphere, border, nrows, ncols)
#     347             image_interp=image_interp, average=average, head_pos=head_pos,
#     348             axes=axes, extrapolate=extrapolate, sphere=sphere, border=border,
# --> 349             nrows=nrows, ncols=ncols)
#     350
#     351     @copy_function_doc_to_method_doc(plot_evoked_field)
#
# ~\anaconda3\lib\site-packages\mne\viz\topomap.py in plot_evoked_topomap(***failed resolving arguments***)
#    1668                 colorbar=colorbar, size=size)
#    1669         elif len(axes) != n_times:
# -> 1670             raise RuntimeError('Axes and times must be equal in sizes.')
#    1671         elif colorbar and colorbar_warn:
#    1672             warn('Colorbar is drawn to the rightmost column of the figure. Be '
#
# RuntimeError: Axes and times must be equal in sizes.
